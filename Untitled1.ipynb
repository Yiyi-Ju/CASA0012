# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

import numpy as np

import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sn

pd.set_option('display.max_rows', 500) # specifies number of rows to show
pd.options.display.float_format = '{:40,.4f}'.format # specifies default number format to 4 decimal places
plt.style.use('ggplot') # specifies that graphs should use ggplot styling
# %matplotlib inline

# %%
df = pd.read_csv('GWR.csv')

# %%
df.describe().T
# Out:
#                                                count  \
# Lat                                       8,989.0000
# Long                                      9,005.0000
# num_Dur                                   9,015.0000
# num_Old                                   9,015.0000
# num_Prd                                   9,015.0000
# num_Pro                                   9,015.0000
# dis_station                               9,015.0000
# dis_airport                               9,015.0000
# Price                                     9,015.0000
#
#                                                 mean  \
# Lat                                          51.4955
# Long                                         -0.1140
# num_Dur                                       1.5700
# num_Old                                       1.9728
# num_Prd                                       1.1662
# num_Pro                                       1.5736
# dis_station                                   9.5436
# dis_airport                                  24.1616
# Price                                   831,103.8232
#
#                                                  std  \
# Lat                                           0.0781
# Long                                          0.1550
# num_Dur                                       0.4951
# num_Old                                       0.1626
# num_Prd                                       0.3723
# num_Pro                                       1.3562
# dis_station                                   5.5293
# dis_airport                                   8.1796
# Price                                 4,307,384.0430
#
#                                                  min  \
# Lat                                          51.2948
# Long                                         -0.4979
# num_Dur                                       1.0000
# num_Old                                       1.0000
# num_Prd                                       1.0000
# num_Pro                                       1.0000
# dis_station                                   0.0700
# dis_airport                                   1.4190
# Price                                       100.0000
#
#                                                  25%  \
# Lat                                          51.4383
# Long                                         -0.2105
# num_Dur                                       1.0000
# num_Old                                       2.0000
# num_Prd                                       1.0000
# num_Pro                                       1.0000
# dis_station                                   4.9310
# dis_airport                                  18.5135
# Price                                   375,000.0000
#
#                                                  50%  \
# Lat                                          51.4913
# Long                                         -0.1161
# num_Dur                                       2.0000
# num_Old                                       2.0000
# num_Prd                                       1.0000
# num_Pro                                       1.3000
# dis_station                                   8.9300
# dis_airport                                  25.3430
# Price                                   500,000.0000
#
#                                                  75%  \
# Lat                                          51.5572
# Long                                         -0.0115
# num_Dur                                       2.0000
# num_Old                                       2.0000
# num_Prd                                       1.0000
# num_Pro                                       1.4000
# dis_station                                  13.7835
# dis_airport                                  30.7955
# Price                                   725,000.0000
#
#                                                  max
# Lat                                          51.6819
# Long                                          0.2740
# num_Dur                                       2.0000
# num_Old                                       2.0000
# num_Prd                                       2.0000
# num_Pro                                       7.0000
# dis_station                                  25.2610
# dis_airport                                  39.9340
# Price                               296,280,000.0000
